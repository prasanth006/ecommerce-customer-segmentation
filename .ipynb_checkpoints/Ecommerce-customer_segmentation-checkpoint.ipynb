# %%
import os

# A list of all the folders we want to create for the project
folders = [
    'data/raw',
    'data/processed',
    'notebooks',
    'outputs/figures',
    'outputs/models',
    'src'
]

# Loop through the list and create each folder
for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f'Created: {folder}')
# Out:
# Created: data/raw
# Created: data/processed
# Created: notebooks
# Created: outputs/figures
# Created: outputs/models
# Created: src
